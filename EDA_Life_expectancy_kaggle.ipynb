# %% [markdown]
# <a href="https://colab.research.google.com/github/igor-kevin/Analise-Penaltis/blob/master/EDA_Life_expectancy_kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Life Expectancy Averaged Dataset
#
#
#
#
# https://www.kaggle.com/datasets/shreyasg23/life-expectancy-averaged-dataset

# %% [markdown]
# O que são os dados:
#
#
# *   Country (país):
# *   Region (região):
# *   Year (ano):
# *   Infant_deaths (mortalidade infantil):
# *   Under_five_deaths (mortalidade infantil para crianças abaixo de 5 anos):
# *   Adult_mortality (mortalidade de adultos):
# *   Alcohol_consumption
# *   Hepatitis_B
# *   Measles
# *   BMI
# *   Polio
# *   Diphtheria
# *   Incidents_HIV
# *   GDP_per_capita
# *   Population_mln
# *   Thinness_ten_nineteen_years
# *   Thinness_five_nine_years
# *   Schooling
# *   Economy_status
# *   Life_expectancy

# %% [markdown]
# ## Importações e carregamento dos dados

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
expec_vida = pd.read_csv('Life-Expectancy-Data-Averaged.csv')
expec_vida.head()
# Out:
#                Country                         Region    Year  Infant_deaths  \
# 0          Afghanistan                           Asia  2007.5       71.08125
# 1              Albania                 Rest of Europe  2007.5       15.25625
# 2              Algeria                         Africa  2007.5       26.75625
# 3               Angola                         Africa  2007.5       88.76875
# 4  Antigua and Barbuda  Central America and Caribbean  2007.5        9.47500
#
#    Under_five_deaths  Adult_mortality  Alcohol_consumption  Hepatitis_B  \
# 0           98.61250       265.804969             0.016125      64.5625
# 1           17.14375        83.132969             4.696875      98.0000
# 2           31.19375       113.439281             0.400625      88.3125
# 3          144.16250       297.844063             4.935625      68.8125
# 4           11.51875       142.478813             7.755000      98.2500
#
# ...

# %% [markdown]
# ## Análise das colunas e detecção de valores faltantes

# %%
expec_vida.columns
# Out:
# Index(['Country', 'Region', 'Infant_deaths', 'Under_five_deaths',
#        'Adult_mortality', 'Alcohol_consumption', 'Hepatitis_B', 'Measles',
#        'BMI', 'Polio', 'Diphtheria', 'Incidents_HIV', 'GDP_per_capita',
#        'Population_mln', 'Thinness_ten_nineteen_years',
#        'Thinness_five_nine_years', 'Schooling', 'Economy_status',
#        'Life_expectancy'],
#       dtype='object')

# %%
expec_vida.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179 entries, 0 to 178
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      179 non-null    object
#  1   Region                       179 non-null    object
#  2   Year                         179 non-null    float64
#  3   Infant_deaths                179 non-null    float64
#  4   Under_five_deaths            179 non-null    float64
#  5   Adult_mortality              179 non-null    float64
#  6   Alcohol_consumption          179 non-null    float64
#  7   Hepatitis_B                  179 non-null    float64
#  8   Measles                      179 non-null    float64
#  9   BMI                          179 non-null    float64
#  10  Polio                        179 non-null    float64
#  11  Diphtheria                   179 non-null    float64
# ...

# %% [markdown]
# Pelas informações do info, temos o dataset sem valores nulos, ou seja, é completamente preenchido.

# %%
expec_vida.describe()
# Out:
#          Year  Infant_deaths  Under_five_deaths  Adult_mortality  \
# count   179.0     179.000000         179.000000       179.000000
# mean   2007.5      30.363792          42.938268       192.251775
# std       0.0      26.725485          42.916952       111.659044
# min    2007.5       2.381250           3.000000        57.710313
# 25%    2007.5       8.159375           9.775000       107.046906
# 50%    2007.5      19.368750          23.137500       164.432406
# 75%    2007.5      48.959375          68.321875       247.523922
# max    2007.5     115.718750         178.725000       572.974312
#
#        Alcohol_consumption  Hepatitis_B     Measles         BMI       Polio  \
# count           179.000000   179.000000  179.000000  179.000000  179.000000
# mean              4.820882    84.292598   77.344972   25.032926   86.499651
# std               3.914554    13.820223   17.315208    2.165490   13.581153
# ...

# %% [markdown]
# Podemos notar que a coluna ano (Year) tem sempre o mesmo valor, então podemos retirar da análise. Neste caso, o ano é sempre o mesmo pois o dataset já é a média de um compilado de dados ao longo dos anos, deixando a coluna ano (Year) com apenas um valor.

# %%
expec_vida.drop('Year', axis=1, inplace=True)

# %%
expec_vida
# Out:
#                  Country                         Region  Infant_deaths  \
# 0            Afghanistan                           Asia       71.08125
# 1                Albania                 Rest of Europe       15.25625
# 2                Algeria                         Africa       26.75625
# 3                 Angola                         Africa       88.76875
# 4    Antigua and Barbuda  Central America and Caribbean        9.47500
# ..                   ...                            ...            ...
# 174        Venezuela, RB                  South America       15.85000
# 175              Vietnam                           Asia       19.50000
# 176          Yemen, Rep.                    Middle East       52.44375
# 177               Zambia                         Africa       60.58125
# 178             Zimbabwe                         Africa       50.16875
#
#      Under_five_deaths  Adult_mortality  Alcohol_consumption  Hepatitis_B  \
# ...
